# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"CUDA Device Count: {torch.cuda.device_count()}")
print(f"CUDA Device Name: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA Available: True
# CUDA Device Count: 1
# CUDA Device Name: Quadro P2000

# %%
import os
import torch.nn as nn
from einops.layers.torch import Rearrange
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchsummary import summary

class MixerBlock(nn.Module):
    def __init__(self, dim, num_patches):
        super().__init__()
        self.pre_layer_norm = nn.LayerNorm(dim)
        self.post_layer_norm = nn.LayerNorm(dim)
        
        self.token_mixer = nn.Sequential(
            nn.Linear(num_patches, dim),
            nn.GELU(),
            nn.Dropout(0.3),
            nn.Linear(dim, num_patches),
            nn.Dropout(0.3)
        )
        
        self.channel_mixer = nn.Sequential(
            nn.Linear(dim, dim),
            nn.GELU(),
            nn.Dropout(0.3),
            nn.Linear(dim, dim),
            nn.Dropout(0.3)
        )
        
    def forward(self, x):
        pre_ln = self.pre_layer_norm(x)
        tm_out = self.token_mixer(pre_ln.transpose(1, 2)).transpose(1, 2)
        tm_out = tm_out + x
        post_ln = self.post_layer_norm(tm_out)
        cm_out = self.channel_mixer(post_ln) + tm_out
        return cm_out

class MLPMixer(nn.Module):
    def __init__(self, input_size, patch_size, dim=512, img_channel=3, layers=12, num_classes=2): 
        super().__init__()
        assert (input_size[0] % patch_size[0]) == 0, 'H must be divisible by patch size'
        assert (input_size[1] % patch_size[1]) == 0, 'W must be divisible by patch size'
        
        num_patches = int(input_size[0] / patch_size[0] * input_size[1] / patch_size[1])
        patch_dim = img_channel * patch_size[0] * patch_size[1]
        
        self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=patch_size[0], p2=patch_size[1]),
            nn.Linear(patch_dim, dim)
        )
         
        self.network = nn.Sequential(*[MixerBlock(dim, num_patches) for _ in range(layers)])
        
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.classifier = nn.Linear(dim, num_classes)
    
    def forward(self, x):
        x = self.to_patch_embedding(x)
        x = self.network(x)
        return self.classifier(self.pool(x.transpose(1, 2)).squeeze(2))

def get_data_loader(data_dir, batch_size=32, image_size=(256, 256)):
    transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.ToTensor(),
    ])
    
    dataset = datasets.ImageFolder(root=data_dir, transform=transform)
    return DataLoader(dataset, batch_size=batch_size, shuffle=True)

def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        # Calculate accuracy
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    
    avg_loss = running_loss / len(train_loader)
    accuracy = correct / total
    return avg_loss, accuracy

def validate(model, val_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            
            preds = torch.argmax(outputs, dim=1)
            correct += (preds == labels).sum().item()
    
    return running_loss / len(val_loader), correct / len(val_loader.dataset)

def get_test_data_loader(data_dir, batch_size=32, image_size=(256, 256)):
    transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.ToTensor(),
    ])
    
    dataset = datasets.ImageFolder(root=data_dir, transform=transform)
    return DataLoader(dataset, batch_size=batch_size, shuffle=False)

def evaluate(model, test_loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    
    accuracy = correct / total
    return accuracy

def main():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    model = MLPMixer(
        input_size=(256, 256),
        patch_size=(16, 16),
        dim=512,
        layers=12,
        num_classes=2  # Binary classification
    ).to(device)
    
    summary(model, input_size=(3, 256, 256))

    train_loader = get_data_loader('./data/split_BC-15/train', batch_size=32)
    val_loader = get_data_loader('./data/split_BC-15/validation', batch_size=32)
    test_loader = get_test_data_loader('./data/split_BC-15/test', batch_size=32)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    
    best_val_loss = float('inf')
    patience = 10
    early_stop_counter = 0

    for epoch in range(100):  # Increased number of epochs
        train_loss, train_accuracy = train(model, train_loader, criterion, optimizer, device)
        val_loss, val_accuracy = validate(model, val_loader, criterion, device)
        
        print(f'Epoch [{epoch+1}/100], Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}')
        
        # Check if validation loss improved
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
            # Save model if validation loss improves
            torch.save(model.state_dict(), 'best_model.pth')
        else:
            early_stop_counter += 1
            
        # Early stopping check
        if early_stop_counter >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break
    
    # Load the best model for testing
    model.load_state_dict(torch.load('best_model.pth'))
    test_accuracy = evaluate(model, test_loader, device)
    print(f'Test Accuracy: {test_accuracy:.4f}')

if __name__ == '__main__':
    main()
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          Rearrange-1             [-1, 256, 768]               0
#             Linear-2             [-1, 256, 512]         393,728
#          LayerNorm-3             [-1, 256, 512]           1,024
#             Linear-4             [-1, 512, 512]         131,584
#               GELU-5             [-1, 512, 512]               0
#            Dropout-6             [-1, 512, 512]               0
#             Linear-7             [-1, 512, 256]         131,328
#            Dropout-8             [-1, 512, 256]               0
#          LayerNorm-9             [-1, 256, 512]           1,024
#            Linear-10             [-1, 256, 512]         262,656
#              GELU-11             [-1, 256, 512]               0
#           Dropout-12             [-1, 256, 512]               0
#            Linear-13             [-1, 256, 512]         262,656
#           Dropout-14             [-1, 256, 512]               0
#        MixerBlock-15             [-1, 256, 512]               0
#         LayerNorm-16             [-1, 256, 512]           1,024
#            Linear-17             [-1, 512, 512]         131,584
#              GELU-18             [-1, 512, 512]               0
#           Dropout-19             [-1, 512, 512]               0
#            Linear-20             [-1, 512, 256]         131,328
#           Dropout-21             [-1, 512, 256]               0
#         LayerNorm-22             [-1, 256, 512]           1,024
#            Linear-23             [-1, 256, 512]         262,656
#              GELU-24             [-1, 256, 512]               0
#           Dropout-25             [-1, 256, 512]               0
#            Linear-26             [-1, 256, 512]         262,656
#           Dropout-27             [-1, 256, 512]               0
#        MixerBlock-28             [-1, 256, 512]               0
#         LayerNorm-29             [-1, 256, 512]           1,024
#            Linear-30             [-1, 512, 512]         131,584
#              GELU-31             [-1, 512, 512]               0
#           Dropout-32             [-1, 512, 512]               0
#            Linear-33             [-1, 512, 256]         131,328
#           Dropout-34             [-1, 512, 256]               0
#         LayerNorm-35             [-1, 256, 512]           1,024
#            Linear-36             [-1, 256, 512]         262,656
#              GELU-37             [-1, 256, 512]               0
#           Dropout-38             [-1, 256, 512]               0
#            Linear-39             [-1, 256, 512]         262,656
#           Dropout-40             [-1, 256, 512]               0
#        MixerBlock-41             [-1, 256, 512]               0
#         LayerNorm-42             [-1, 256, 512]           1,024
#            Linear-43             [-1, 512, 512]         131,584
#              GELU-44             [-1, 512, 512]               0
#           Dropout-45             [-1, 512, 512]               0
#            Linear-46             [-1, 512, 256]         131,328
#           Dropout-47             [-1, 512, 256]               0
#         LayerNorm-48             [-1, 256, 512]           1,024
#            Linear-49             [-1, 256, 512]         262,656
#              GELU-50             [-1, 256, 512]               0
#           Dropout-51             [-1, 256, 512]               0
#            Linear-52             [-1, 256, 512]         262,656
#           Dropout-53             [-1, 256, 512]               0
#        MixerBlock-54             [-1, 256, 512]               0
#         LayerNorm-55             [-1, 256, 512]           1,024
#            Linear-56             [-1, 512, 512]         131,584
#              GELU-57             [-1, 512, 512]               0
#           Dropout-58             [-1, 512, 512]               0
#            Linear-59             [-1, 512, 256]         131,328
#           Dropout-60             [-1, 512, 256]               0
#         LayerNorm-61             [-1, 256, 512]           1,024
#            Linear-62             [-1, 256, 512]         262,656
#              GELU-63             [-1, 256, 512]               0
#           Dropout-64             [-1, 256, 512]               0
#            Linear-65             [-1, 256, 512]         262,656
#           Dropout-66             [-1, 256, 512]               0
#        MixerBlock-67             [-1, 256, 512]               0
#         LayerNorm-68             [-1, 256, 512]           1,024
#            Linear-69             [-1, 512, 512]         131,584
#              GELU-70             [-1, 512, 512]               0
#           Dropout-71             [-1, 512, 512]               0
#            Linear-72             [-1, 512, 256]         131,328
#           Dropout-73             [-1, 512, 256]               0
#         LayerNorm-74             [-1, 256, 512]           1,024
#            Linear-75             [-1, 256, 512]         262,656
#              GELU-76             [-1, 256, 512]               0
#           Dropout-77             [-1, 256, 512]               0
#            Linear-78             [-1, 256, 512]         262,656
#           Dropout-79             [-1, 256, 512]               0
#        MixerBlock-80             [-1, 256, 512]               0
#         LayerNorm-81             [-1, 256, 512]           1,024
#            Linear-82             [-1, 512, 512]         131,584
#              GELU-83             [-1, 512, 512]               0
#           Dropout-84             [-1, 512, 512]               0
#            Linear-85             [-1, 512, 256]         131,328
#           Dropout-86             [-1, 512, 256]               0
#         LayerNorm-87             [-1, 256, 512]           1,024
#            Linear-88             [-1, 256, 512]         262,656
#              GELU-89             [-1, 256, 512]               0
#           Dropout-90             [-1, 256, 512]               0
#            Linear-91             [-1, 256, 512]         262,656
#           Dropout-92             [-1, 256, 512]               0
#        MixerBlock-93             [-1, 256, 512]               0
#         LayerNorm-94             [-1, 256, 512]           1,024
#            Linear-95             [-1, 512, 512]         131,584
#              GELU-96             [-1, 512, 512]               0
#           Dropout-97             [-1, 512, 512]               0
#            Linear-98             [-1, 512, 256]         131,328
#           Dropout-99             [-1, 512, 256]               0
#        LayerNorm-100             [-1, 256, 512]           1,024
#           Linear-101             [-1, 256, 512]         262,656
#             GELU-102             [-1, 256, 512]               0
#          Dropout-103             [-1, 256, 512]               0
#           Linear-104             [-1, 256, 512]         262,656
#          Dropout-105             [-1, 256, 512]               0
#       MixerBlock-106             [-1, 256, 512]               0
#        LayerNorm-107             [-1, 256, 512]           1,024
#           Linear-108             [-1, 512, 512]         131,584
#             GELU-109             [-1, 512, 512]               0
#          Dropout-110             [-1, 512, 512]               0
#           Linear-111             [-1, 512, 256]         131,328
#          Dropout-112             [-1, 512, 256]               0
#        LayerNorm-113             [-1, 256, 512]           1,024
#           Linear-114             [-1, 256, 512]         262,656
#             GELU-115             [-1, 256, 512]               0
#          Dropout-116             [-1, 256, 512]               0
#           Linear-117             [-1, 256, 512]         262,656
#          Dropout-118             [-1, 256, 512]               0
#       MixerBlock-119             [-1, 256, 512]               0
#        LayerNorm-120             [-1, 256, 512]           1,024
#           Linear-121             [-1, 512, 512]         131,584
#             GELU-122             [-1, 512, 512]               0
#          Dropout-123             [-1, 512, 512]               0
#           Linear-124             [-1, 512, 256]         131,328
#          Dropout-125             [-1, 512, 256]               0
#        LayerNorm-126             [-1, 256, 512]           1,024
#           Linear-127             [-1, 256, 512]         262,656
#             GELU-128             [-1, 256, 512]               0
#          Dropout-129             [-1, 256, 512]               0
#           Linear-130             [-1, 256, 512]         262,656
#          Dropout-131             [-1, 256, 512]               0
#       MixerBlock-132             [-1, 256, 512]               0
#        LayerNorm-133             [-1, 256, 512]           1,024
#           Linear-134             [-1, 512, 512]         131,584
#             GELU-135             [-1, 512, 512]               0
#          Dropout-136             [-1, 512, 512]               0
#           Linear-137             [-1, 512, 256]         131,328
#          Dropout-138             [-1, 512, 256]               0
#        LayerNorm-139             [-1, 256, 512]           1,024
#           Linear-140             [-1, 256, 512]         262,656
#             GELU-141             [-1, 256, 512]               0
#          Dropout-142             [-1, 256, 512]               0
#           Linear-143             [-1, 256, 512]         262,656
#          Dropout-144             [-1, 256, 512]               0
#       MixerBlock-145             [-1, 256, 512]               0
#        LayerNorm-146             [-1, 256, 512]           1,024
#           Linear-147             [-1, 512, 512]         131,584
#             GELU-148             [-1, 512, 512]               0
#          Dropout-149             [-1, 512, 512]               0
#           Linear-150             [-1, 512, 256]         131,328
#          Dropout-151             [-1, 512, 256]               0
#        LayerNorm-152             [-1, 256, 512]           1,024
#           Linear-153             [-1, 256, 512]         262,656
#             GELU-154             [-1, 256, 512]               0
#          Dropout-155             [-1, 256, 512]               0
#           Linear-156             [-1, 256, 512]         262,656
#          Dropout-157             [-1, 256, 512]               0
#       MixerBlock-158             [-1, 256, 512]               0
# AdaptiveAvgPool1d-159               [-1, 512, 1]               0
#           Linear-160                    [-1, 2]           1,026
# ================================================================
# Total params: 9,878,018
# Trainable params: 9,878,018
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 194.50
# Params size (MB): 37.68
# Estimated Total Size (MB): 232.94
# ----------------------------------------------------------------
# Epoch [1/100], Train Loss: 0.7784, Train Accuracy: 0.4887, Val Loss: 0.6915, Val Accuracy: 0.5007
# Epoch [2/100], Train Loss: 0.7000, Train Accuracy: 0.4968, Val Loss: 0.6913, Val Accuracy: 0.4993
# Epoch [3/100], Train Loss: 0.6955, Train Accuracy: 0.5377, Val Loss: 0.7673, Val Accuracy: 0.4993
# Epoch [4/100], Train Loss: 0.7047, Train Accuracy: 0.5023, Val Loss: 0.6825, Val Accuracy: 0.5102
# Epoch [5/100], Train Loss: 0.6922, Train Accuracy: 0.5358, Val Loss: 0.7041, Val Accuracy: 0.5061
# Epoch [6/100], Train Loss: 0.7074, Train Accuracy: 0.5027, Val Loss: 0.7408, Val Accuracy: 0.4993
# Epoch [7/100], Train Loss: 0.6964, Train Accuracy: 0.5277, Val Loss: 0.7739, Val Accuracy: 0.4993
# Epoch [8/100], Train Loss: 0.6875, Train Accuracy: 0.5499, Val Loss: 0.7459, Val Accuracy: 0.5292
# Epoch [9/100], Train Loss: 0.7085, Train Accuracy: 0.4973, Val Loss: 0.6756, Val Accuracy: 0.5115
# Epoch [10/100], Train Loss: 0.6879, Train Accuracy: 0.5476, Val Loss: 0.6984, Val Accuracy: 0.5183
# Epoch [11/100], Train Loss: 0.6878, Train Accuracy: 0.5554, Val Loss: 0.6662, Val Accuracy: 0.5875
# Epoch [12/100], Train Loss: 0.6872, Train Accuracy: 0.5517, Val Loss: 0.6997, Val Accuracy: 0.5007
# Epoch [13/100], Train Loss: 0.6566, Train Accuracy: 0.6121, Val Loss: 0.8582, Val Accuracy: 0.5780
# Epoch [14/100], Train Loss: 0.6467, Train Accuracy: 0.6239, Val Loss: 0.6698, Val Accuracy: 0.6744
# Epoch [15/100], Train Loss: 0.6437, Train Accuracy: 0.6198, Val Loss: 0.5616, Val Accuracy: 0.6676
# Epoch [16/100], Train Loss: 0.5913, Train Accuracy: 0.6915, Val Loss: 0.4269, Val Accuracy: 0.8100
# Epoch [17/100], Train Loss: 0.4935, Train Accuracy: 0.7632, Val Loss: 0.3774, Val Accuracy: 0.8372
# Epoch [18/100], Train Loss: 0.6401, Train Accuracy: 0.6397, Val Loss: 0.4259, Val Accuracy: 0.8100
# Epoch [19/100], Train Loss: 0.4515, Train Accuracy: 0.7981, Val Loss: 0.3290, Val Accuracy: 0.8792
# Epoch [20/100], Train Loss: 0.3457, Train Accuracy: 0.8562, Val Loss: 0.4399, Val Accuracy: 0.8168
# Epoch [21/100], Train Loss: 0.3134, Train Accuracy: 0.8643, Val Loss: 0.3102, Val Accuracy: 0.8630
# Epoch [22/100], Train Loss: 0.2746, Train Accuracy: 0.8875, Val Loss: 0.3372, Val Accuracy: 0.8765
# Epoch [23/100], Train Loss: 0.2504, Train Accuracy: 0.8943, Val Loss: 0.2191, Val Accuracy: 0.9091
# Epoch [24/100], Train Loss: 0.2271, Train Accuracy: 0.9056, Val Loss: 0.2676, Val Accuracy: 0.8901
# Epoch [25/100], Train Loss: 0.2010, Train Accuracy: 0.9201, Val Loss: 0.2217, Val Accuracy: 0.9132
# Epoch [26/100], Train Loss: 0.1736, Train Accuracy: 0.9315, Val Loss: 0.2841, Val Accuracy: 0.9091
# Epoch [27/100], Train Loss: 0.1463, Train Accuracy: 0.9401, Val Loss: 0.3182, Val Accuracy: 0.8874
# Epoch [28/100], Train Loss: 0.1695, Train Accuracy: 0.9369, Val Loss: 0.3109, Val Accuracy: 0.9064
# Epoch [29/100], Train Loss: 0.1420, Train Accuracy: 0.9419, Val Loss: 0.2153, Val Accuracy: 0.9308
# Epoch [30/100], Train Loss: 0.1383, Train Accuracy: 0.9433, Val Loss: 0.2933, Val Accuracy: 0.9118
# Epoch [31/100], Train Loss: 0.1788, Train Accuracy: 0.9242, Val Loss: 0.2351, Val Accuracy: 0.9240
# Epoch [32/100], Train Loss: 0.1063, Train Accuracy: 0.9583, Val Loss: 0.2734, Val Accuracy: 0.9322
# Epoch [33/100], Train Loss: 0.0855, Train Accuracy: 0.9719, Val Loss: 0.3094, Val Accuracy: 0.9077
# Epoch [34/100], Train Loss: 0.1099, Train Accuracy: 0.9592, Val Loss: 0.2586, Val Accuracy: 0.9240
# Epoch [35/100], Train Loss: 0.0624, Train Accuracy: 0.9764, Val Loss: 0.3945, Val Accuracy: 0.9132
# Epoch [36/100], Train Loss: 0.0861, Train Accuracy: 0.9701, Val Loss: 0.3387, Val Accuracy: 0.9145
# Epoch [37/100], Train Loss: 0.0665, Train Accuracy: 0.9750, Val Loss: 0.3957, Val Accuracy: 0.9104
# Epoch [38/100], Train Loss: 0.0571, Train Accuracy: 0.9850, Val Loss: 0.4010, Val Accuracy: 0.9104
# Epoch [39/100], Train Loss: 0.0476, Train Accuracy: 0.9805, Val Loss: 0.3019, Val Accuracy: 0.9227
# Early stopping at epoch 39
# C:\Users\5530\AppData\Local\Temp\ipykernel_24156\2764618354.py:183: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
# Test Accuracy: 0.9198
